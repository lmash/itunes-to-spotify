# %%
from data import pickles
from enums import filepath, db_name, Field, Category

import queries
from tinydb import TinyDB, Query

# %%
## Always

# %%
    db = TinyDB(filepath / db_name)
    db_field = Field()
    db_category = Category()

# %%
queries.display_all_albums(db)
# Out:
# Apple album: Don't Look Back Search album: Don't Look Back
# Apple album: Songs About Jane Search album: Songs About Jane
# Apple album: Doo-Wops & Hooligans (Deluxe) Search album: Doo-Wops & Hooligans (Deluxe)
# Apple album: Highway to Hell Search album: Highway to Hell
# Apple album: Lost in Istanbul - Single Search album: Lost in Istanbul - Single
# Apple album: For Your Entertainment Search album: For Your Entertainment
# Apple album: Best of Search album: Best of
# Apple album: She Wolf - Single Search album: She Wolf - Single
# Apple album: Hail To The Thief Search album: Hail To The Thief
# Apple album: Something Different - EP Search album: Something Different - EP
# Apple album: I Would Walk 500 Miles - Single Search album: I Would Walk 500 Miles - Single
# Apple album: Hunky Dory (2015 Remaster) Search album: Hunky Dory (2015 Remaster)
# Apple album: Trash Search album: Trash
# Apple album: = Search album: =
# ...

# %%
queries.display_album_artist_with_uri(database=db)
# Out:
# 0

# %%
pickled_album_artist = pickles.get_pickled_album_artist()

# %%
for key, value in pickled_album_artist.items():
    print(f'key {key} value {value}')
# Out:
# key Gold|ABBA value spotify:album:2cKZfaz7GiGtZEeQNj1RyR|spotify:artist:0LcJLqbBmaGUft1e9Mm8HV
# key Up All Night|Razorlight value spotify:album:6iRS8yRhnTgNEQrBoB2azm|spotify:artist:450iujbtN6XgiA9pv6fVZz
# key 21|Adele value spotify:album:0Lg1uZvI312TPqxNWShFXL|spotify:artist:4dpARuHxo51G3z768sgnrY
# key Different World|Alan Walker value spotify:album:3nzuGtN3nXARvvecier4K0|spotify:artist:7vk5e3vY1uw9plTHJAMwjN
# key In Real Life|TryHardNinja value spotify:album:55PmOlwaWduudUdWoc7nCb|spotify:artist:0B7Y5KDNScTBzeN7DY74YG
# key The Fame|Lady Gaga value spotify:album:1jpUMnKpRlng1OJN7LJauV|spotify:artist:1HY2Jd0NmPuamShAr6KMms
# key Showbiz|Muse value spotify:album:6AyUVv7MnxxTuijp4WmrhO|spotify:artist:12Chz98pHFMPJEknJQMWvI
# key Superflu|Saint Privat value spotify:album:6wLv7Khtdw2PVznFvOzBDA|spotify:artist:7hrruNuPITt3N9zLMdbjGz
# key Amnesiac|Radiohead value spotify:album:1HrMmB5useeZ0F5lHrMvl0|spotify:artist:4Z8W4fKeB5YxbusRsdQVPb
# ...
